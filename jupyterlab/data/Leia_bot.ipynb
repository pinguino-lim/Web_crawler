# %%
import telegram   #텔레그램 모듈을 가져옵니다.

# %%
my_token = '521121170:AAGRbhTDEG9ZuXOMhNK2HSNs3M1ZFPac2U4'   #토큰을 변수에 저장합니다.

bot = telegram.Bot(token = my_token)   #bot을 선언합니다.

updates = bot.getUpdates()  #업데이트 내역을 받아옵니다.

for u in updates :   # 내역중 메세지를 출력합니다.
    print(u.message['chat']['first_name'],": ",u.message['txt'])
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/telegram/vendor/ptb_urllib3/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401                     # otherwise it looks like a programming error was the cause.
# --> 402                     six.raise_from(e, None)
#     403         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/lib/python3.6/site-packages/telegram/vendor/ptb_urllib3/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.6/site-packages/telegram/vendor/ptb_urllib3/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397                 try:
# --> 398                     httplib_response = conn.getresponse()
# ...

# %%
chat_id = bot.getUpdates()[-1].message.chat.id #가장 최근에 온 메세지의 chat id를 가져옵니다

bot.sendMessage(chat_id = chat_id, text="Soy Leia Gata bot!")
